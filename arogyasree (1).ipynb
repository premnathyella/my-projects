# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\premnath\\Desktop\\arogyasri wit (1).csv")

# %%
df.head()
# Out:
#    .No Financial Year  District Constituency  Preauth Initiated Count  \
# 0    1      2011-2012  Adilabad     Adilabad                        1
# 1    2      2012-2013  Adilabad     Adilabad                        1
# 2    3      2013-2014  Adilabad     Adilabad                       60
# 3    4      2014-2015  Adilabad     Adilabad                     1227
# 4    5      2015-2016  Adilabad     Adilabad                     1374
#
#    Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 0                     15000                       1                    15000
# 1                     50000                       0                        0
# 2                   2134104                      59                  2043590
# 3                  35790026                    1106                 31499026
# 4                  40881562                    1237                 35871029
#
#    Surgeries Done Count  Surgeries Done Amount
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 10 columns):
# .No                         747 non-null int64
# Financial Year              746 non-null object
# District                    747 non-null object
# Constituency                746 non-null object
# Preauth Initiated Count     747 non-null int64
# Preauth Initiated Amount    747 non-null int64
# Preauth Approved Count      747 non-null int64
# Preauth Approved Amount     747 non-null int64
# Surgeries Done Count        747 non-null int64
# Surgeries Done Amount       747 non-null int64
# dtypes: int64(7), object(3)
# memory usage: 58.4+ KB

# %%
df.drop([".No"],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Financial Year  District Constituency  Preauth Initiated Count  \
# 0      2011-2012  Adilabad     Adilabad                        1
# 1      2012-2013  Adilabad     Adilabad                        1
# 2      2013-2014  Adilabad     Adilabad                       60
# 3      2014-2015  Adilabad     Adilabad                     1227
# 4      2015-2016  Adilabad     Adilabad                     1374
#
#    Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 0                     15000                       1                    15000
# 1                     50000                       0                        0
# 2                   2134104                      59                  2043590
# 3                  35790026                    1106                 31499026
# 4                  40881562                    1237                 35871029
#
#    Surgeries Done Count  Surgeries Done Amount
# 0                     1                  15000
# ...

# %%
df1=df.rename(columns={"Surgeries Done Count":"SurgeriesCount","Surgeries Done Amount":"Surgeriesamount"})

# %%
df1.head()
# Out:
#   Financial Year  District Constituency  Preauth Initiated Count  \
# 0      2011-2012  Adilabad     Adilabad                        1
# 1      2012-2013  Adilabad     Adilabad                        1
# 2      2013-2014  Adilabad     Adilabad                       60
# 3      2014-2015  Adilabad     Adilabad                     1227
# 4      2015-2016  Adilabad     Adilabad                     1374
#
#    Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 0                     15000                       1                    15000
# 1                     50000                       0                        0
# 2                   2134104                      59                  2043590
# 3                  35790026                    1106                 31499026
# 4                  40881562                    1237                 35871029
#
#    SurgeriesCount  Surgeriesamount
# 0               1            15000
# 1               0                0
# ...

# %%
df1.groupby(["District","Surgeriesamount","Financial Year","Constituency"]).SurgeriesCount.value_counts()
# Out:
# District  Surgeriesamount  Financial Year  Constituency       SurgeriesCount
# Adilabad  0                2008-2009       Khanapur           0                 1
#                            2011-2012       Khanapur           0                 1
#                            2012-2013       Adilabad           0                 1
#                                            Bellampalle (SC)   0                 1
#                                            Sirpur             0                 1
#           15000            2011-2012       Adilabad           1                 1
#           22000            2009-2010       Mancherial         1                 1
#           30000            2009-2010       Chennur(SC)        1                 1
#                            2012-2013       Boath              1                 1
#                                            Mudhole            1                 1
# ...

# %%
df1[df1["SurgeriesCount"]==0].count()
# Out:
# Financial Year              33
# District                    33
# Constituency                33
# Preauth Initiated Count     33
# Preauth Initiated Amount    33
# Preauth Approved Count      33
# Preauth Approved Amount     33
# SurgeriesCount              33
# Surgeriesamount             33
# dtype: int64

# %%
df1.groupby(["District"]).count()
# Out:
#               Financial Year  Constituency  Preauth Initiated Count  \
# District
# Adilabad                  62            62                       62
# Grand Total                0             0                        1
# Hyderabad                 80            80                       80
# Karimnagar                77            77                       77
# Khammam                   61            61                       61
# Mahabubnagar              88            88                       88
# Medak                     59            59                       59
# Nalgonda                  83            83                       83
# Nizamabad                 49            49                       49
# Ranga Reddy               98            98                       98
# Warangal                  89            89                       89
#
#               Preauth Initiated Amount  Preauth Approved Count  \
# District
# Adilabad                            62                      62
# ...

# %%
df1[df1["Financial Year"]=="2014-2015"].count()
# Out:
# Financial Year              117
# District                    117
# Constituency                117
# Preauth Initiated Count     117
# Preauth Initiated Amount    117
# Preauth Approved Count      117
# Preauth Approved Amount     117
# SurgeriesCount              117
# Surgeriesamount             117
# dtype: int64

# %%
x=df1[df1["Financial Year"]=="2014-2015"]
y=df1[df1["Financial Year"]=="2015-2016"]

# %%
y
# Out:
#     Financial Year     District       Constituency  Preauth Initiated Count  \
# 4        2015-2016     Adilabad           Adilabad                     1374
# 10       2015-2016     Adilabad      Asifabad (ST)                      803
# 16       2015-2016     Adilabad   Bellampalle (SC)                     1150
# 22       2015-2016     Adilabad              Boath                     1142
# 29       2015-2016     Adilabad        Chennur(SC)                     1233
# 36       2015-2016     Adilabad           Khanapur                     1455
# 42       2015-2016     Adilabad         Mancherial                     1819
# 48       2015-2016     Adilabad            Mudhole                     1705
# 53       2015-2016     Adilabad             Nirmal                     1312
# 59       2015-2016     Adilabad             Sirpur                     1598
# 64       2015-2016    Hyderabad           Amberpet                      551
# ...

# %%
A=df1[df1["District"]=="Adilabad"]
A.head()
# Out:
#   Financial Year  District Constituency  Preauth Initiated Count  \
# 0      2011-2012  Adilabad     Adilabad                        1
# 1      2012-2013  Adilabad     Adilabad                        1
# 2      2013-2014  Adilabad     Adilabad                       60
# 3      2014-2015  Adilabad     Adilabad                     1227
# 4      2015-2016  Adilabad     Adilabad                     1374
#
#    Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 0                     15000                       1                    15000
# 1                     50000                       0                        0
# 2                   2134104                      59                  2043590
# 3                  35790026                    1106                 31499026
# 4                  40881562                    1237                 35871029
#
#    SurgeriesCount  Surgeriesamount
# 0               1            15000
# 1               0                0
# ...

# %%
b=A[A["Financial Year"]=="2014-2015"]
b
# Out:
#    Financial Year  District      Constituency  Preauth Initiated Count  \
# 3       2014-2015  Adilabad          Adilabad                     1227
# 9       2014-2015  Adilabad     Asifabad (ST)                      699
# 15      2014-2015  Adilabad  Bellampalle (SC)                      875
# 21      2014-2015  Adilabad             Boath                     1056
# 28      2014-2015  Adilabad       Chennur(SC)                      983
# 35      2014-2015  Adilabad          Khanapur                     1160
# 41      2014-2015  Adilabad        Mancherial                     1434
# 47      2014-2015  Adilabad           Mudhole                     1511
# 52      2014-2015  Adilabad            Nirmal                     1152
# 58      2014-2015  Adilabad            Sirpur                     1234
#
#     Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 3                   35790026                    1106                 31499026
# ...

# %% [markdown]
# # the num of surgeries done in the year 2014-2015 in adilabad

# %%
b["SurgeriesCount"].sum()
# Out:
# 10566

# %% [markdown]
# # the total amount spent on surgeries in the year 2014-2015 in adilabad

# %%
b["Surgeriesamount"].sum()
# Out:
# 285667994

# %%
c=A[A["Financial Year"]=="2015-2016"]
c
# Out:
#    Financial Year  District      Constituency  Preauth Initiated Count  \
# 4       2015-2016  Adilabad          Adilabad                     1374
# 10      2015-2016  Adilabad     Asifabad (ST)                      803
# 16      2015-2016  Adilabad  Bellampalle (SC)                     1150
# 22      2015-2016  Adilabad             Boath                     1142
# 29      2015-2016  Adilabad       Chennur(SC)                     1233
# 36      2015-2016  Adilabad          Khanapur                     1455
# 42      2015-2016  Adilabad        Mancherial                     1819
# 48      2015-2016  Adilabad           Mudhole                     1705
# 53      2015-2016  Adilabad            Nirmal                     1312
# 59      2015-2016  Adilabad            Sirpur                     1598
#
#     Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 4                   40881562                    1237                 35871029
# ...

# %% [markdown]
# # surgeries done in 2015-16 in adilabad

# %%
c["SurgeriesCount"].sum()
# Out:
# 12706

# %% [markdown]
# # amount spent in 2015-16 in adilabad

# %%
c["Surgeriesamount"].sum()
# Out:
# 339645602

# %%
d=A[A["Financial Year"]=="2016-2017"]
d
# Out:
#    Financial Year  District      Constituency  Preauth Initiated Count  \
# 5       2016-2017  Adilabad          Adilabad                     1355
# 11      2016-2017  Adilabad     Asifabad (ST)                      783
# 17      2016-2017  Adilabad  Bellampalle (SC)                     1197
# 23      2016-2017  Adilabad             Boath                     1252
# 30      2016-2017  Adilabad       Chennur(SC)                     1491
# 37      2016-2017  Adilabad          Khanapur                     1635
# 43      2016-2017  Adilabad        Mancherial                     1938
# 49      2016-2017  Adilabad           Mudhole                     1739
# 54      2016-2017  Adilabad            Nirmal                     1253
# 60      2016-2017  Adilabad            Sirpur                     1769
#
#     Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 5                   38910235                    1257                 35078225
# ...

# %% [markdown]
# # sugeries done in 16-17 in adilabad

# %%
d["SurgeriesCount"].sum()
# Out:
# 13593

# %% [markdown]
# # amount spent in 16-17 in adilabad

# %%
d["Surgeriesamount"].sum()
# Out:
# 367490457

# %%
e=A[A["Financial Year"]=="2017-2018"]
e
# Out:
#    Financial Year  District      Constituency  Preauth Initiated Count  \
# 6       2017-2018  Adilabad          Adilabad                     1706
# 12      2017-2018  Adilabad     Asifabad (ST)                     1096
# 18      2017-2018  Adilabad  Bellampalle (SC)                     1360
# 24      2017-2018  Adilabad             Boath                     1584
# 31      2017-2018  Adilabad       Chennur(SC)                     1733
# 38      2017-2018  Adilabad          Khanapur                     1941
# 44      2017-2018  Adilabad        Mancherial                     2106
# 50      2017-2018  Adilabad           Mudhole                     2462
# 55      2017-2018  Adilabad            Nirmal                     1907
# 61      2017-2018  Adilabad            Sirpur                     1998
#
#     Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 6                   50295504                    1596                 46336508
# ...

# %% [markdown]
# # no of surgeries in 17-18 in adilabad

# %%
e["SurgeriesCount"].sum()
# Out:
# 16927

# %% [markdown]
# # amount spent in 17-18 in adilabad

# %%
e["Surgeriesamount"].sum()
# Out:
# 443027551

# %% [markdown]
# # total no of surgeries done in adilabad

# %%
total=b["SurgeriesCount"].sum()+e["SurgeriesCount"].sum()+c["SurgeriesCount"].sum()+d["SurgeriesCount"].sum()
total
# Out:
# 53792

# %% [markdown]
# # total amount spent in adilabad

# %%
amount=b["Surgeriesamount"].sum()+e["Surgeriesamount"].sum()+c["Surgeriesamount"].sum()+d["Surgeriesamount"].sum()
amount
# Out:
# 1435831604

# %%
W=df1[df1["District"]=="Warangal"]
W.head()
# Out:
#     Financial Year  District Constituency  Preauth Initiated Count  \
# 657      2011-2012  Warangal  Bhupalpalle                        1
# 658      2012-2013  Warangal  Bhupalpalle                        1
# 659      2013-2014  Warangal  Bhupalpalle                      122
# 660      2014-2015  Warangal  Bhupalpalle                     2827
# 661      2015-2016  Warangal  Bhupalpalle                     3506
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 657                    100000                       0
# 658                     20000                       1
# 659                   4177074                     122
# 660                  79963067                    2660
# 661                  98179119                    3276
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 657                        0               0                0
# 658                    20000               1            20000
# ...

# %%
W1=W[W["Financial Year"]=="2014-2015"]
W1
# Out:
#     Financial Year  District       Constituency  Preauth Initiated Count  \
# 660      2014-2015  Warangal        Bhupalpalle                     2827
# 667      2014-2015  Warangal           Dornakal                     2031
# 673      2014-2015  Warangal  Ghanpur (Station)                     3197
# 681      2014-2015  Warangal            Jangoan                     2427
# 687      2014-2015  Warangal        Mahabubabad                     2432
# 694      2014-2015  Warangal              Mulug                     1981
# 701      2014-2015  Warangal          Narsampet                     3058
# 708      2014-2015  Warangal         Palakurthi                     2732
# 715      2014-2015  Warangal             Parkal                     3161
# 720      2014-2015  Warangal       Waradhanapet                      519
# 728      2014-2015  Warangal   Waradhanapet(SC)                     3236
# 734      2014-2015  Warangal      Warangal East                     2943
# ...

# %% [markdown]
# # SUM OF SURGERIES IN 14-15 in warangal

# %%
W1["SurgeriesCount"].sum()
# Out:
# 30797

# %% [markdown]
# # amount spent on SURGERIES IN 14-15 in warangal

# %%
W1["Surgeriesamount"].sum()
# Out:
# 810419642

# %%
W2=W[W["Financial Year"]=="2015-2016"]
W2
# Out:
#     Financial Year  District       Constituency  Preauth Initiated Count  \
# 661      2015-2016  Warangal        Bhupalpalle                     3506
# 668      2015-2016  Warangal           Dornakal                     2363
# 674      2015-2016  Warangal  Ghanpur (Station)                     3658
# 682      2015-2016  Warangal            Jangoan                     2974
# 688      2015-2016  Warangal        Mahabubabad                     2635
# 695      2015-2016  Warangal              Mulug                     2460
# 702      2015-2016  Warangal          Narsampet                     3594
# 709      2015-2016  Warangal         Palakurthi                     3191
# 716      2015-2016  Warangal             Parkal                     3638
# 721      2015-2016  Warangal       Waradhanapet                      640
# 729      2015-2016  Warangal   Waradhanapet(SC)                     3734
# 735      2015-2016  Warangal      Warangal East                     3243
# ...

# %% [markdown]
# # surgeries in 15-16

# %%
W2["SurgeriesCount"].sum()
# Out:
# 35891

# %% [markdown]
# # amount spent in 15-16

# %%
W2["Surgeriesamount"].sum()
# Out:
# 957743553

# %%
W3=W[W["Financial Year"]=="2016-2017"]
W3
# Out:
#     Financial Year  District       Constituency  Preauth Initiated Count  \
# 662      2016-2017  Warangal        Bhupalpalle                     3749
# 669      2016-2017  Warangal           Dornakal                     2715
# 675      2016-2017  Warangal  Ghanpur (Station)                     3976
# 683      2016-2017  Warangal            Jangoan                     3115
# 689      2016-2017  Warangal        Mahabubabad                     3282
# 696      2016-2017  Warangal              Mulug                     2571
# 703      2016-2017  Warangal          Narsampet                     3658
# 710      2016-2017  Warangal         Palakurthi                     3343
# 717      2016-2017  Warangal             Parkal                     3689
# 722      2016-2017  Warangal       Waradhanapet                      650
# 730      2016-2017  Warangal   Waradhanapet(SC)                     3800
# 736      2016-2017  Warangal      Warangal East                     3661
# ...

# %% [markdown]
# # sugeries done in 16-17

# %%
W3["SurgeriesCount"].sum()
# Out:
# 38608

# %% [markdown]
# # amount spent in 16-17

# %%
W3["Surgeriesamount"].sum()
# Out:
# 1012146745

# %%
W4=W[W["Financial Year"]=="2017-2018"]
W4
# Out:
#     Financial Year  District       Constituency  Preauth Initiated Count  \
# 663      2017-2018  Warangal        Bhupalpalle                     4359
# 670      2017-2018  Warangal           Dornakal                     2854
# 676      2017-2018  Warangal  Ghanpur (Station)                     4464
# 684      2017-2018  Warangal            Jangoan                     3542
# 690      2017-2018  Warangal        Mahabubabad                     3791
# 697      2017-2018  Warangal              Mulug                     2997
# 704      2017-2018  Warangal          Narsampet                     4292
# 711      2017-2018  Warangal         Palakurthi                     3851
# 718      2017-2018  Warangal             Parkal                     4528
# 723      2017-2018  Warangal       Waradhanapet                      824
# 731      2017-2018  Warangal   Waradhanapet(SC)                     4508
# 737      2017-2018  Warangal      Warangal East                     3817
# ...

# %% [markdown]
# # no of surgeries in 17-18

# %%
W4["SurgeriesCount"].sum()
# Out:
# 44126

# %% [markdown]
# # amount spent in 17-18

# %%
W4["Surgeriesamount"].sum()
# Out:
# 1119743786

# %% [markdown]
# # total no of surgeries in warangal

# %%
total1=W1["SurgeriesCount"].sum()+W2["SurgeriesCount"].sum()+W3["SurgeriesCount"].sum()+W4["SurgeriesCount"].sum()
total1
# Out:
# 149422

# %% [markdown]
# # total amount spent in warangal

# %%
amount1=W1["Surgeriesamount"].sum()+W2["Surgeriesamount"].sum()+W3["Surgeriesamount"].sum()+W4["Surgeriesamount"].sum()
amount1
# Out:
# 3900053726

# %%
h=df1[df1["District"]=="Hyderabad"]
h.head(2)
# Out:
#    Financial Year   District Constituency  Preauth Initiated Count  \
# 62      2013-2014  Hyderabad     Amberpet                       18
# 63      2014-2015  Hyderabad     Amberpet                      350
#
#     Preauth Initiated Amount  Preauth Approved Count  Preauth Approved Amount  \
# 62                    537235                      18                   537235
# 63                   8696700                     332                  8037758
#
#     SurgeriesCount  Surgeriesamount
# 62              15           403985
# 63             332          8037758

# %%
h1=h[h["Financial Year"]=="2014-2015"]
h1
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 63       2014-2015  Hyderabad           Amberpet                      350
# 68       2014-2015  Hyderabad         Bhadurpura                      325
# 75       2014-2015  Hyderabad  Chandrayana Gutta                     2662
# 84       2014-2015  Hyderabad          Charminar                     2819
# 89       2014-2015  Hyderabad      Jubilee Hills                       90
# 94       2014-2015  Hyderabad             Karwan                      417
# 100      2014-2015  Hyderabad        Khairatabad                      534
# 108      2014-2015  Hyderabad           Malakpet                     2527
# 113      2014-2015  Hyderabad        Musheerabad                      312
# 118      2014-2015  Hyderabad           Nampally                      976
# 123      2014-2015  Hyderabad       Sanath Nagar                      210
# 130      2014-2015  Hyderabad       Secunderabad                     1273
# ...

# %%
h1["SurgeriesCount"].sum()
# Out:
# 14762

# %%
h1["Surgeriesamount"].sum()
# Out:
# 362633521

# %%
h2=h[h["Financial Year"]=="2015-2016"]
h2
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 64       2015-2016  Hyderabad           Amberpet                      551
# 69       2015-2016  Hyderabad         Bhadurpura                      459
# 76       2015-2016  Hyderabad  Chandrayana Gutta                     3172
# 85       2015-2016  Hyderabad          Charminar                     3665
# 90       2015-2016  Hyderabad      Jubilee Hills                      100
# 95       2015-2016  Hyderabad             Karwan                      596
# 101      2015-2016  Hyderabad        Khairatabad                      920
# 109      2015-2016  Hyderabad           Malakpet                     2803
# 114      2015-2016  Hyderabad        Musheerabad                      416
# 119      2015-2016  Hyderabad           Nampally                     1511
# 124      2015-2016  Hyderabad       Sanath Nagar                      228
# 131      2015-2016  Hyderabad       Secunderabad                     1644
# ...

# %%
h2["SurgeriesCount"].sum()
# Out:
# 18694

# %%
h2["Surgeriesamount"].sum()
# Out:
# 449770805

# %%
h3=h[h["Financial Year"]=="2016-2017"]
h3
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 65       2016-2017  Hyderabad           Amberpet                      564
# 70       2016-2017  Hyderabad         Bhadurpura                      529
# 77       2016-2017  Hyderabad  Chandrayana Gutta                     3277
# 86       2016-2017  Hyderabad          Charminar                     4007
# 91       2016-2017  Hyderabad      Jubilee Hills                       88
# 96       2016-2017  Hyderabad             Karwan                      729
# 102      2016-2017  Hyderabad        Khairatabad                      892
# 110      2016-2017  Hyderabad           Malakpet                     3163
# 115      2016-2017  Hyderabad        Musheerabad                      520
# 120      2016-2017  Hyderabad           Nampally                     1739
# 125      2016-2017  Hyderabad       Sanath Nagar                      236
# 132      2016-2017  Hyderabad       Secunderabad                     1612
# ...

# %%
h3["SurgeriesCount"].sum()
# Out:
# 19958

# %%
h3["Surgeriesamount"].sum()
# Out:
# 463740159

# %%
h4=h[h["Financial Year"]=="2017-2018"]
h4
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 66       2017-2018  Hyderabad           Amberpet                      679
# 71       2017-2018  Hyderabad         Bhadurpura                      673
# 78       2017-2018  Hyderabad  Chandrayana Gutta                     3450
# 87       2017-2018  Hyderabad          Charminar                     5125
# 92       2017-2018  Hyderabad      Jubilee Hills                       99
# 97       2017-2018  Hyderabad             Karwan                      873
# 103      2017-2018  Hyderabad        Khairatabad                     1056
# 111      2017-2018  Hyderabad           Malakpet                     3543
# 116      2017-2018  Hyderabad        Musheerabad                      638
# 121      2017-2018  Hyderabad           Nampally                     1878
# 126      2017-2018  Hyderabad       Sanath Nagar                      360
# 133      2017-2018  Hyderabad       Secunderabad                     1964
# ...

# %%
h4["SurgeriesCount"].sum()
# Out:
# 23049

# %%
h4["Surgeriesamount"].sum()
# Out:
# 513753693

# %% [markdown]
# # total amount spent in hyderabad

# %%
amount2=h1["Surgeriesamount"].sum()+h2["Surgeriesamount"].sum()+h3["Surgeriesamount"].sum()+h4["Surgeriesamount"].sum()
amount2
# Out:
# 1789898178

# %% [markdown]
# # total surgeries done in hyderabad

# %%
tsurgeries=h1["SurgeriesCount"].sum()+h2["SurgeriesCount"].sum()+h3["SurgeriesCount"].sum()+h4["SurgeriesCount"].sum()
tsurgeries
# Out:
# 76463

# %%
k=df1[df1["District"]=="Karimnagar"]
k.head()
# Out:
#     Financial Year    District Constituency  Preauth Initiated Count  \
# 142      2008-2009  Karimnagar  Choppadandi                        1
# 143      2012-2013  Karimnagar  Choppadandi                        1
# 144      2013-2014  Karimnagar  Choppadandi                       51
# 145      2014-2015  Karimnagar  Choppadandi                     2241
# 146      2015-2016  Karimnagar  Choppadandi                     2832
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 142                     60000                       1
# 143                     35000                       0
# 144                   1972364                      51
# 145                  60779131                    2140
# 146                  76321808                    2692
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 142                    60000               1            60000
# 143                        0               0                0
# ...

# %%
k4=k[k["Financial Year"]=="2017-2018"]
k4
# Out:
#     Financial Year    District Constituency  Preauth Initiated Count  \
# 148      2017-2018  Karimnagar  Choppadandi                     3389
# 154      2017-2018  Karimnagar   Dharmapuri                     3507
# 160      2017-2018  Karimnagar     Husnabad                     4115
# 166      2017-2018  Karimnagar    Huzurabad                     3886
# 172      2017-2018  Karimnagar      Jagtial                     2973
# 177      2017-2018  Karimnagar   Karimnagar                     3081
# 183      2017-2018  Karimnagar      Koratla                     3281
# 188      2017-2018  Karimnagar   Manakondur                     2799
# 195      2017-2018  Karimnagar     Manthani                     4492
# 201      2017-2018  Karimnagar   Peddapalle                     1781
# 208      2017-2018  Karimnagar   Ramagundam                     2064
# 213      2017-2018  Karimnagar     Sircilla                     2849
# 218      2017-2018  Karimnagar   Vemulawada                     2101
#
# ...

# %%
k4["SurgeriesCount"].sum()
# Out:
# 38368

# %%
k4["Surgeriesamount"].sum()
# Out:
# 989209327

# %%
k1=k[k["Financial Year"]=="2014-2015"]
k1
# Out:
#     Financial Year    District Constituency  Preauth Initiated Count  \
# 145      2014-2015  Karimnagar  Choppadandi                     2241
# 151      2014-2015  Karimnagar   Dharmapuri                     2627
# 157      2014-2015  Karimnagar     Husnabad                     2968
# 163      2014-2015  Karimnagar    Huzurabad                     2938
# 169      2014-2015  Karimnagar      Jagtial                     2171
# 174      2014-2015  Karimnagar   Karimnagar                     2289
# 180      2014-2015  Karimnagar      Koratla                     2391
# 185      2014-2015  Karimnagar   Manakondur                     2029
# 192      2014-2015  Karimnagar     Manthani                     2731
# 198      2014-2015  Karimnagar   Peddapalle                     1245
# 205      2014-2015  Karimnagar   Ramagundam                     1313
# 210      2014-2015  Karimnagar     Sircilla                     1835
# 215      2014-2015  Karimnagar   Vemulawada                     1459
#
# ...

# %%
k1["SurgeriesCount"].sum()
# Out:
# 26847

# %%
k1["Surgeriesamount"].sum()
# Out:
# 703640604

# %%
k2=k[k["Financial Year"]=="2016-2017"]
k2
# Out:
#     Financial Year    District Constituency  Preauth Initiated Count  \
# 147      2016-2017  Karimnagar  Choppadandi                     2834
# 153      2016-2017  Karimnagar   Dharmapuri                     3104
# 159      2016-2017  Karimnagar     Husnabad                     3729
# 165      2016-2017  Karimnagar    Huzurabad                     3524
# 171      2016-2017  Karimnagar      Jagtial                     2668
# 176      2016-2017  Karimnagar   Karimnagar                     2574
# 182      2016-2017  Karimnagar      Koratla                     2995
# 187      2016-2017  Karimnagar   Manakondur                     2509
# 194      2016-2017  Karimnagar     Manthani                     3796
# 200      2016-2017  Karimnagar   Peddapalle                     1612
# 207      2016-2017  Karimnagar   Ramagundam                     1591
# 212      2016-2017  Karimnagar     Sircilla                     2502
# 217      2016-2017  Karimnagar   Vemulawada                     1738
#
# ...

# %%
k2["SurgeriesCount"].sum()
# Out:
# 33426

# %%
k2["Surgeriesamount"].sum()
# Out:
# 877039332

# %%
k3=k[k["Financial Year"]=="2015-2016"]
k3
# Out:
#     Financial Year    District Constituency  Preauth Initiated Count  \
# 146      2015-2016  Karimnagar  Choppadandi                     2832
# 152      2015-2016  Karimnagar   Dharmapuri                     2903
# 158      2015-2016  Karimnagar     Husnabad                     3391
# 164      2015-2016  Karimnagar    Huzurabad                     3243
# 170      2015-2016  Karimnagar      Jagtial                     2449
# 175      2015-2016  Karimnagar   Karimnagar                     2597
# 181      2015-2016  Karimnagar      Koratla                     2829
# 186      2015-2016  Karimnagar   Manakondur                     2214
# 193      2015-2016  Karimnagar     Manthani                     3477
# 199      2015-2016  Karimnagar   Peddapalle                     1392
# 206      2015-2016  Karimnagar   Ramagundam                     1602
# 211      2015-2016  Karimnagar     Sircilla                     2264
# 216      2015-2016  Karimnagar   Vemulawada                     1836
#
# ...

# %%
k3["SurgeriesCount"].sum()
# Out:
# 31388

# %%
k3["Surgeriesamount"].sum()
# Out:
# 835811963

# %% [markdown]
# # total amount spent in karimnager

# %%
kamount=k1["Surgeriesamount"].sum()+k2["Surgeriesamount"].sum()+k3["Surgeriesamount"].sum()+k4["Surgeriesamount"].sum()
kamount
# Out:
# 3405701226

# %% [markdown]
# # total surgeries done

# %%
ksurgeries=k1["SurgeriesCount"].sum()+k2["SurgeriesCount"].sum()+k3["SurgeriesCount"].sum()+k4["SurgeriesCount"].sum()
ksurgeries
# Out:
# 130029

# %%
ka=df1[df1["District"]=="Khammam"]
ka
# Out:
#     Financial Year District       Constituency  Preauth Initiated Count  \
# 219      2012-2013  Khammam   Aswaraopeta (ST)                        2
# 220      2013-2014  Khammam   Aswaraopeta (ST)                       41
# 221      2014-2015  Khammam   Aswaraopeta (ST)                     1003
# 222      2015-2016  Khammam   Aswaraopeta (ST)                     1020
# 223      2016-2017  Khammam   Aswaraopeta (ST)                      963
# 224      2017-2018  Khammam   Aswaraopeta (ST)                     1192
# 225      2008-2009  Khammam  Bhadrachalam (ST)                        1
# 226      2012-2013  Khammam  Bhadrachalam (ST)                        2
# 227      2013-2014  Khammam  Bhadrachalam (ST)                       56
# 228      2014-2015  Khammam  Bhadrachalam (ST)                     1141
# 229      2015-2016  Khammam  Bhadrachalam (ST)                      886
# 230      2016-2017  Khammam  Bhadrachalam (ST)                      913
# ...

# %%
ka1=ka[ka["Financial Year"]=="2014-2015"]
ka1
# Out:
#     Financial Year District       Constituency  Preauth Initiated Count  \
# 221      2014-2015  Khammam   Aswaraopeta (ST)                     1003
# 228      2014-2015  Khammam  Bhadrachalam (ST)                     1141
# 235      2014-2015  Khammam            Khammam                     2494
# 241      2014-2015  Khammam         Kothagudem                     1546
# 247      2014-2015  Khammam       Madhira (SC)                     2052
# 253      2014-2015  Khammam             Palair                     1447
# 258      2014-2015  Khammam      Pinapaka (ST)                      953
# 264      2014-2015  Khammam    Sathupalle (SC)                     1734
# 270      2014-2015  Khammam           Wyra(ST)                     1680
# 276      2014-2015  Khammam      Yellandu (ST)                     1591
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 221                  29170847                     956
# 228                  29364294                    1102
# ...

# %%
ka1["SurgeriesCount"].sum()
# Out:
# 14781

# %%
ka1["Surgeriesamount"].sum()
# Out:
# 415663284

# %%
ka2=ka[ka["Financial Year"]=="2015-2016"]
ka2
# Out:
#     Financial Year District       Constituency  Preauth Initiated Count  \
# 222      2015-2016  Khammam   Aswaraopeta (ST)                     1020
# 229      2015-2016  Khammam  Bhadrachalam (ST)                      886
# 236      2015-2016  Khammam            Khammam                     2813
# 242      2015-2016  Khammam         Kothagudem                     1769
# 248      2015-2016  Khammam       Madhira (SC)                     2399
# 254      2015-2016  Khammam             Palair                     1519
# 259      2015-2016  Khammam      Pinapaka (ST)                     1126
# 265      2015-2016  Khammam    Sathupalle (SC)                     1926
# 271      2015-2016  Khammam           Wyra(ST)                     1807
# 277      2015-2016  Khammam      Yellandu (ST)                     1821
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 222                  31759669                     952
# 229                  25074320                     842
# ...

# %%
ka2["SurgeriesCount"].sum()
# Out:
# 16072

# %%
ka2["Surgeriesamount"].sum()
# Out:
# 456683624

# %%
ka3=ka[ka["Financial Year"]=="2016-2017"]
ka3
# Out:
#     Financial Year District       Constituency  Preauth Initiated Count  \
# 223      2016-2017  Khammam   Aswaraopeta (ST)                      963
# 230      2016-2017  Khammam  Bhadrachalam (ST)                      913
# 237      2016-2017  Khammam            Khammam                     3220
# 243      2016-2017  Khammam         Kothagudem                     2052
# 249      2016-2017  Khammam       Madhira (SC)                     2221
# 255      2016-2017  Khammam             Palair                     1830
# 260      2016-2017  Khammam      Pinapaka (ST)                     1146
# 266      2016-2017  Khammam    Sathupalle (SC)                     1990
# 272      2016-2017  Khammam           Wyra(ST)                     2006
# 278      2016-2017  Khammam      Yellandu (ST)                     2019
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 223                  29255423                     905
# 230                  26322012                     844
# ...

# %%
ka3["SurgeriesCount"].sum()
# Out:
# 17274

# %%
ka3["Surgeriesamount"].sum()
# Out:
# 478043312

# %%
ka4=ka[ka["Financial Year"]=="2017-2018"]
ka4
# Out:
#     Financial Year District       Constituency  Preauth Initiated Count  \
# 224      2017-2018  Khammam   Aswaraopeta (ST)                     1192
# 231      2017-2018  Khammam  Bhadrachalam (ST)                      993
# 238      2017-2018  Khammam            Khammam                     3427
# 244      2017-2018  Khammam         Kothagudem                     2194
# 250      2017-2018  Khammam       Madhira (SC)                     2626
# 256      2017-2018  Khammam             Palair                     2060
# 261      2017-2018  Khammam      Pinapaka (ST)                     1528
# 267      2017-2018  Khammam    Sathupalle (SC)                     2228
# 273      2017-2018  Khammam           Wyra(ST)                     1957
# 279      2017-2018  Khammam      Yellandu (ST)                     2056
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 224                  34504301                    1129
# 231                  28103016                     911
# ...

# %%
ka4["SurgeriesCount"].sum()
# Out:
# 19072

# %%
ka4["Surgeriesamount"].sum()
# Out:
# 513976821

# %% [markdown]
# # total surgeries done

# %%
kasurgeries=ka1["SurgeriesCount"].sum()+ka2["SurgeriesCount"].sum()+ka3["SurgeriesCount"].sum()+ka4["SurgeriesCount"].sum()
kasurgeries
# Out:
# 67199

# %% [markdown]
# # total amount spent

# %%
katotal=ka1["Surgeriesamount"].sum()+ka2["Surgeriesamount"].sum()+ka3["Surgeriesamount"].sum()+ka4["Surgeriesamount"].sum()
katotal
# Out:
# 1864367041

# %%
m=df1[df1["District"]=="Mahabubnagar"]
m.head(2)
# Out:
#     Financial Year      District Constituency  Preauth Initiated Count  \
# 280      2012-2013  Mahabubnagar     Achampet                        2
# 281      2013-2014  Mahabubnagar     Achampet                       90
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 280                     52000                       2
# 281                   2771140                      87
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 280                    52000               0                0
# 281                  2590038              86          2586788

# %%
m1=m[m["Financial Year"]=="2014-2015"]
m1
# Out:
#     Financial Year      District  Constituency  Preauth Initiated Count  \
# 282      2014-2015  Mahabubnagar      Achampet                     1544
# 289      2014-2015  Mahabubnagar       Alampur                     1415
# 295      2014-2015  Mahabubnagar    Devarkadra                     1983
# 302      2014-2015  Mahabubnagar        Gadwal                     1449
# 308      2014-2015  Mahabubnagar     Jadcherla                     1695
# 314      2014-2015  Mahabubnagar   Kalwakurthy                     1957
# 320      2014-2015  Mahabubnagar      Kodangal                     1337
# 326      2014-2015  Mahabubnagar      Kollapur                     1922
# 332      2014-2015  Mahabubnagar  Mahabubnagar                     2037
# 338      2014-2015  Mahabubnagar       Makthal                     1720
# 344      2014-2015  Mahabubnagar  Nagarkurnool                     1961
# 350      2014-2015  Mahabubnagar    Narayanpet                     1585
# ...

# %%
m1["SurgeriesCount"].sum()
# Out:
# 22183

# %%
m1["Surgeriesamount"].sum()
# Out:
# 608421209

# %%
m2=m[m["Financial Year"]=="2015-2016"]
m2
# Out:
#     Financial Year      District  Constituency  Preauth Initiated Count  \
# 283      2015-2016  Mahabubnagar      Achampet                     1983
# 290      2015-2016  Mahabubnagar       Alampur                     1887
# 296      2015-2016  Mahabubnagar    Devarkadra                     2651
# 303      2015-2016  Mahabubnagar        Gadwal                     1656
# 309      2015-2016  Mahabubnagar     Jadcherla                     2199
# 315      2015-2016  Mahabubnagar   Kalwakurthy                     2325
# 321      2015-2016  Mahabubnagar      Kodangal                     1717
# 327      2015-2016  Mahabubnagar      Kollapur                     2313
# 333      2015-2016  Mahabubnagar  Mahabubnagar                     2331
# 339      2015-2016  Mahabubnagar       Makthal                     1901
# 345      2015-2016  Mahabubnagar  Nagarkurnool                     2456
# 351      2015-2016  Mahabubnagar    Narayanpet                     2019
# ...

# %%
m2["SurgeriesCount"].sum()
# Out:
# 27105

# %%
m2["Surgeriesamount"].sum()
# Out:
# 720710243

# %%
m3=m[m["Financial Year"]=="2016-2017"]
m3
# Out:
#     Financial Year      District  Constituency  Preauth Initiated Count  \
# 284      2016-2017  Mahabubnagar      Achampet                     1943
# 291      2016-2017  Mahabubnagar       Alampur                     1808
# 297      2016-2017  Mahabubnagar    Devarkadra                     2938
# 304      2016-2017  Mahabubnagar        Gadwal                     1597
# 310      2016-2017  Mahabubnagar     Jadcherla                     2573
# 316      2016-2017  Mahabubnagar   Kalwakurthy                     2428
# 322      2016-2017  Mahabubnagar      Kodangal                     2138
# 328      2016-2017  Mahabubnagar      Kollapur                     2440
# 334      2016-2017  Mahabubnagar  Mahabubnagar                     2744
# 340      2016-2017  Mahabubnagar       Makthal                     2412
# 346      2016-2017  Mahabubnagar  Nagarkurnool                     3104
# 352      2016-2017  Mahabubnagar    Narayanpet                     2389
# ...

# %%
m3["SurgeriesCount"].sum()
# Out:
# 30644

# %%
m3["Surgeriesamount"].sum()
# Out:
# 783319810

# %%
m4=m[m["Financial Year"]=="2017-2018"]
m4
# Out:
#     Financial Year      District  Constituency  Preauth Initiated Count  \
# 285      2017-2018  Mahabubnagar      Achampet                     2280
# 292      2017-2018  Mahabubnagar       Alampur                     1835
# 298      2017-2018  Mahabubnagar    Devarkadra                     3710
# 305      2017-2018  Mahabubnagar        Gadwal                     1843
# 311      2017-2018  Mahabubnagar     Jadcherla                     2983
# 317      2017-2018  Mahabubnagar   Kalwakurthy                     2779
# 323      2017-2018  Mahabubnagar      Kodangal                     2297
# 329      2017-2018  Mahabubnagar      Kollapur                     2612
# 335      2017-2018  Mahabubnagar  Mahabubnagar                     3538
# 341      2017-2018  Mahabubnagar       Makthal                     2751
# 347      2017-2018  Mahabubnagar  Nagarkurnool                     3183
# 353      2017-2018  Mahabubnagar    Narayanpet                     2950
# ...

# %%
m4["SurgeriesCount"].sum()
# Out:
# 35068

# %%
m4["Surgeriesamount"].sum()
# Out:
# 856930576

# %% [markdown]
# # total no of surgeries in mbnr

# %%
msurgeries=m1["SurgeriesCount"].sum()+m2["SurgeriesCount"].sum()+m3["SurgeriesCount"].sum()+m4["SurgeriesCount"].sum()
msurgeries
# Out:
# 115000

# %% [markdown]
# # total amount spent in mbnr

# %%
mamount=m1["Surgeriesamount"].sum()+m2["Surgeriesamount"].sum()+m3["Surgeriesamount"].sum()+m4["Surgeriesamount"].sum()
mamount
# Out:
# 2969381838

# %%
me=df1[df1["District"]=="Medak"]
me.head()
# Out:
#     Financial Year District Constituency  Preauth Initiated Count  \
# 368      2012-2013    Medak       Andole                        1
# 369      2013-2014    Medak       Andole                       92
# 370      2014-2015    Medak       Andole                     1572
# 371      2015-2016    Medak       Andole                     1835
# 372      2016-2017    Medak       Andole                     1873
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 368                     50000                       1
# 369                   2672504                      90
# 370                  46601947                    1470
# 371                  53604940                    1702
# 372                  54681695                    1748
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 368                    50000               1            50000
# 369                  2563938              89          2560688
# ...

# %%
me1=me[me["Financial Year"]=="2014-2015"]
me1
# Out:
#     Financial Year District Constituency  Preauth Initiated Count  \
# 370      2014-2015    Medak       Andole                     1572
# 376      2014-2015    Medak       Dubbak                     1587
# 382      2014-2015    Medak       Gajwel                     2256
# 388      2014-2015    Medak        Medak                     1836
# 394      2014-2015    Medak  Narayankhed                     1244
# 400      2014-2015    Medak     Narsapur                     1697
# 406      2014-2015    Medak   Patancheru                     1366
# 412      2014-2015    Medak   Sangareddy                     1464
# 417      2014-2015    Medak     Siddipet                     1856
# 423      2014-2015    Medak    Zahirabad                     1572
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 370                  46601947                    1470
# 376                  46917476                    1483
# 382                  67669309                    2113
# ...

# %%
me1["SurgeriesCount"].sum()
# Out:
# 15338

# %%
me1["Surgeriesamount"].sum()
# Out:
# 431679403

# %%
me2=me[me["Financial Year"]=="2015-2016"]
me2
# Out:
#     Financial Year District Constituency  Preauth Initiated Count  \
# 371      2015-2016    Medak       Andole                     1835
# 377      2015-2016    Medak       Dubbak                     2066
# 383      2015-2016    Medak       Gajwel                     2768
# 389      2015-2016    Medak        Medak                     2255
# 395      2015-2016    Medak  Narayankhed                     1449
# 401      2015-2016    Medak     Narsapur                     2202
# 407      2015-2016    Medak   Patancheru                     1836
# 413      2015-2016    Medak   Sangareddy                     1782
# 418      2015-2016    Medak     Siddipet                     2394
# 424      2015-2016    Medak    Zahirabad                     1916
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 371                  53604940                    1702
# 377                  58134503                    1949
# 383                  78044695                    2575
# ...

# %%
me2["SurgeriesCount"].sum()
# Out:
# 19184

# %%
me2["Surgeriesamount"].sum()
# Out:
# 522286820

# %%
me3=me[me["Financial Year"]=="2016-2017"]
me3
# Out:
#     Financial Year District Constituency  Preauth Initiated Count  \
# 372      2016-2017    Medak       Andole                     1873
# 378      2016-2017    Medak       Dubbak                     2255
# 384      2016-2017    Medak       Gajwel                     2865
# 390      2016-2017    Medak        Medak                     2271
# 396      2016-2017    Medak  Narayankhed                     1581
# 402      2016-2017    Medak     Narsapur                     2291
# 408      2016-2017    Medak   Patancheru                     1786
# 414      2016-2017    Medak   Sangareddy                     1809
# 419      2016-2017    Medak     Siddipet                     2469
# 425      2016-2017    Medak    Zahirabad                     1930
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 372                  54681695                    1748
# 378                  63117586                    2126
# 384                  78597390                    2674
# ...

# %%
me3["SurgeriesCount"].sum()
# Out:
# 19821

# %%
me3["Surgeriesamount"].sum()
# Out:
# 531306257

# %%
me4=me[me["Financial Year"]=="2017-2018"]
me4
# Out:
#     Financial Year District Constituency  Preauth Initiated Count  \
# 373      2017-2018    Medak       Andole                     2014
# 379      2017-2018    Medak       Dubbak                     2824
# 385      2017-2018    Medak       Gajwel                     3486
# 391      2017-2018    Medak        Medak                     2582
# 397      2017-2018    Medak  Narayankhed                     1678
# 403      2017-2018    Medak     Narsapur                     2394
# 409      2017-2018    Medak   Patancheru                     2015
# 415      2017-2018    Medak   Sangareddy                     2086
# 420      2017-2018    Medak     Siddipet                     3015
# 426      2017-2018    Medak    Zahirabad                     1977
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 373                  56542040                    1885
# 379                  73664115                    2660
# 385                  92485677                    3275
# ...

# %%
me4["SurgeriesCount"].sum()
# Out:
# 22608

# %%
me4["Surgeriesamount"].sum()
# Out:
# 598573448

# %% [markdown]
# # no of surgeries in medak

# %%
mesur=me1["SurgeriesCount"].sum()+me2["SurgeriesCount"].sum()+me3["SurgeriesCount"].sum()+me4["SurgeriesCount"].sum()
mesur
# Out:
# 76951

# %% [markdown]
# # total amount spent in medak

# %%
meamount=me1["Surgeriesamount"].sum()+me2["Surgeriesamount"].sum()+me3["Surgeriesamount"].sum()+me4["Surgeriesamount"].sum()
meamount
# Out:
# 2083845928

# %%
n=df1[df1["District"]=="Nalgonda"]
n.head(1)
# Out:
#     Financial Year  District Constituency  Preauth Initiated Count  \
# 427      2011-2012  Nalgonda        Alair                        1
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 427                     50000                       1
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 427                    50000               0                0

# %%
n1=n[n["Financial Year"]=="2014-2015"]
n1
# Out:
#     Financial Year  District        Constituency  Preauth Initiated Count  \
# 430      2014-2015  Nalgonda               Alair                     2550
# 436      2014-2015  Nalgonda             Bhongir                     2228
# 444      2014-2015  Nalgonda    Devarakonda (ST)                     2416
# 449      2014-2015  Nalgonda          Huzurnagar                     1392
# 458      2014-2015  Nalgonda               Kodad                     1995
# 466      2014-2015  Nalgonda         Miryalaguda                     2301
# 472      2014-2015  Nalgonda            Munugode                     2132
# 480      2014-2015  Nalgonda     Nagarjuna Sagar                     2081
# 487      2014-2015  Nalgonda       Nakrekal (SC)                     2854
# 493      2014-2015  Nalgonda            Nalgonda                     2164
# 500      2014-2015  Nalgonda            Suryapet                     2164
# 506      2014-2015  Nalgonda  Thungathurthi (SC)                     2407
#
# ...

# %%
n1["SurgeriesCount"].sum()
# Out:
# 25070

# %%
n1["Surgeriesamount"].sum()
# Out:
# 655709538

# %%
n2=n[n["Financial Year"]=="2015-2016"]
n2
# Out:
#     Financial Year  District        Constituency  Preauth Initiated Count  \
# 431      2015-2016  Nalgonda               Alair                     2905
# 437      2015-2016  Nalgonda             Bhongir                     2661
# 445      2015-2016  Nalgonda    Devarakonda (ST)                     2831
# 450      2015-2016  Nalgonda          Huzurnagar                     1558
# 459      2015-2016  Nalgonda               Kodad                     2380
# 467      2015-2016  Nalgonda         Miryalaguda                     2631
# 473      2015-2016  Nalgonda            Munugode                     2569
# 481      2015-2016  Nalgonda     Nagarjuna Sagar                     2344
# 488      2015-2016  Nalgonda       Nakrekal (SC)                     2977
# 494      2015-2016  Nalgonda            Nalgonda                     2338
# 501      2015-2016  Nalgonda            Suryapet                     2428
# 507      2015-2016  Nalgonda  Thungathurthi (SC)                     2557
#
# ...

# %%
n2["SurgeriesCount"].sum()
# Out:
# 28400

# %%
n2["Surgeriesamount"].sum()
# Out:
# 736660981

# %%
n3=n[n["Financial Year"]=="2016-2017"]
n3
# Out:
#     Financial Year  District        Constituency  Preauth Initiated Count  \
# 432      2016-2017  Nalgonda               Alair                     2945
# 438      2016-2017  Nalgonda             Bhongir                     2636
# 446      2016-2017  Nalgonda    Devarakonda (ST)                     3254
# 451      2016-2017  Nalgonda          Huzurnagar                     1727
# 460      2016-2017  Nalgonda               Kodad                     2477
# 468      2016-2017  Nalgonda         Miryalaguda                     2678
# 474      2016-2017  Nalgonda            Munugode                     2747
# 482      2016-2017  Nalgonda     Nagarjuna Sagar                     2595
# 489      2016-2017  Nalgonda       Nakrekal (SC)                     3386
# 495      2016-2017  Nalgonda            Nalgonda                     2547
# 502      2016-2017  Nalgonda            Suryapet                     2496
# 508      2016-2017  Nalgonda  Thungathurthi (SC)                     2848
#
# ...

# %%
n3["SurgeriesCount"].sum()
# Out:
# 30616

# %%
n3["Surgeriesamount"].sum()
# Out:
# 793417189

# %%
n4=n[n["Financial Year"]=="2017-2018"]
n4
# Out:
#     Financial Year  District        Constituency  Preauth Initiated Count  \
# 433      2017-2018  Nalgonda               Alair                     3271
# 439      2017-2018  Nalgonda             Bhongir                     3008
# 447      2017-2018  Nalgonda    Devarakonda (ST)                     3504
# 452      2017-2018  Nalgonda          Huzurnagar                     2062
# 461      2017-2018  Nalgonda               Kodad                     2753
# 469      2017-2018  Nalgonda         Miryalaguda                     3168
# 475      2017-2018  Nalgonda            Munugode                     3171
# 483      2017-2018  Nalgonda     Nagarjuna Sagar                     3125
# 490      2017-2018  Nalgonda       Nakrekal (SC)                     3865
# 496      2017-2018  Nalgonda            Nalgonda                     3097
# 503      2017-2018  Nalgonda            Suryapet                     2822
# 509      2017-2018  Nalgonda  Thungathurthi (SC)                     3410
#
# ...

# %%
n4["SurgeriesCount"].sum()
# Out:
# 35198

# %%
n4["Surgeriesamount"].sum()
# Out:
# 898497502

# %% [markdown]
# # total no of surgeries in nalgonda

# %%
nsurgeries=n1["SurgeriesCount"].sum()+n2["SurgeriesCount"].sum()+n3["SurgeriesCount"].sum()+n4["SurgeriesCount"].sum()
nsurgeries
# Out:
# 119284

# %% [markdown]
# # total amount spent in nalgonda

# %%
namount=n1["Surgeriesamount"].sum()+n2["Surgeriesamount"].sum()+n3["Surgeriesamount"].sum()+n4["Surgeriesamount"].sum()
namount
# Out:
# 3084285210

# %%
r=df1[df1["District"]=="Ranga Reddy"]
r.head()
# Out:
#     Financial Year     District Constituency  Preauth Initiated Count  \
# 559      2008-2009  Ranga Reddy     Chevella                        1
# 560      2011-2012  Ranga Reddy     Chevella                        1
# 561      2012-2013  Ranga Reddy     Chevella                        5
# 562      2013-2014  Ranga Reddy     Chevella                      100
# 563      2014-2015  Ranga Reddy     Chevella                     1855
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 559                     20000                       1
# 560                     40000                       1
# 561                    220000                       5
# 562                   2967403                     100
# 563                  52904931                    1727
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 559                    20000               1            20000
# 560                    40000               1            40000
# ...

# %%
r1=r[r["Financial Year"]=="2014-2015"]
r1
# Out:
#     Financial Year     District     Constituency  Preauth Initiated Count  \
# 563      2014-2015  Ranga Reddy         Chevella                     1855
# 569      2014-2015  Ranga Reddy    Ibrahimpatnam                     2520
# 577      2014-2015  Ranga Reddy       Kukatpally                     2849
# 586      2014-2015  Ranga Reddy        L.B.Nagar                     3963
# 592      2014-2015  Ranga Reddy      Maheshwaram                     1020
# 599      2014-2015  Ranga Reddy       Malkajgiri                     1539
# 606      2014-2015  Ranga Reddy          Medchal                     3418
# 613      2014-2015  Ranga Reddy            Pargi                     1602
# 619      2014-2015  Ranga Reddy     Quthbullapur                     2824
# 627      2014-2015  Ranga Reddy    Rajendranagar                     2886
# 633      2014-2015  Ranga Reddy  Serilingampally                     1219
# 640      2014-2015  Ranga Reddy           Tandur                     1238
# ...

# %%
r1["SurgeriesCount"].sum()
# Out:
# 28629

# %%
r1["Surgeriesamount"].sum()
# Out:
# 755513383

# %%
r2=r[r["Financial Year"]=="2015-2016"]
r2
# Out:
#     Financial Year     District     Constituency  Preauth Initiated Count  \
# 564      2015-2016  Ranga Reddy         Chevella                     2067
# 570      2015-2016  Ranga Reddy    Ibrahimpatnam                     3294
# 578      2015-2016  Ranga Reddy       Kukatpally                     3420
# 587      2015-2016  Ranga Reddy        L.B.Nagar                     4346
# 593      2015-2016  Ranga Reddy      Maheshwaram                     1197
# 600      2015-2016  Ranga Reddy       Malkajgiri                     1801
# 607      2015-2016  Ranga Reddy          Medchal                     3976
# 614      2015-2016  Ranga Reddy            Pargi                     2045
# 620      2015-2016  Ranga Reddy     Quthbullapur                     3449
# 628      2015-2016  Ranga Reddy    Rajendranagar                     3220
# 634      2015-2016  Ranga Reddy  Serilingampally                     1638
# 641      2015-2016  Ranga Reddy           Tandur                     1440
# ...

# %%
r2["SurgeriesCount"].sum()
# Out:
# 34166

# %%
r2["Surgeriesamount"].sum()
# Out:
# 877013364

# %%
r3=r[r["Financial Year"]=="2016-2017"]
r3
# Out:
#     Financial Year     District     Constituency  Preauth Initiated Count  \
# 565      2016-2017  Ranga Reddy         Chevella                     2014
# 571      2016-2017  Ranga Reddy    Ibrahimpatnam                     3290
# 579      2016-2017  Ranga Reddy       Kukatpally                     3112
# 588      2016-2017  Ranga Reddy        L.B.Nagar                     4625
# 594      2016-2017  Ranga Reddy      Maheshwaram                     1208
# 601      2016-2017  Ranga Reddy       Malkajgiri                     1799
# 608      2016-2017  Ranga Reddy          Medchal                     4076
# 615      2016-2017  Ranga Reddy            Pargi                     2068
# 621      2016-2017  Ranga Reddy     Quthbullapur                     3620
# 629      2016-2017  Ranga Reddy    Rajendranagar                     3322
# 635      2016-2017  Ranga Reddy  Serilingampally                     1543
# 642      2016-2017  Ranga Reddy           Tandur                     1556
# ...

# %%
r3["SurgeriesCount"].sum()
# Out:
# 34752

# %%
r3["Surgeriesamount"].sum()
# Out:
# 885203163

# %%
r4=r[r["Financial Year"]=="2017-2018"]
r4
# Out:
#     Financial Year     District     Constituency  Preauth Initiated Count  \
# 566      2017-2018  Ranga Reddy         Chevella                     2224
# 572      2017-2018  Ranga Reddy    Ibrahimpatnam                     3371
# 580      2017-2018  Ranga Reddy       Kukatpally                     3497
# 589      2017-2018  Ranga Reddy        L.B.Nagar                     4853
# 595      2017-2018  Ranga Reddy      Maheshwaram                     1161
# 602      2017-2018  Ranga Reddy       Malkajgiri                     2034
# 609      2017-2018  Ranga Reddy          Medchal                     4621
# 616      2017-2018  Ranga Reddy            Pargi                     2582
# 622      2017-2018  Ranga Reddy     Quthbullapur                     3865
# 630      2017-2018  Ranga Reddy    Rajendranagar                     3538
# 636      2017-2018  Ranga Reddy  Serilingampally                     1770
# 643      2017-2018  Ranga Reddy           Tandur                     1677
# ...

# %%
r4["SurgeriesCount"].sum()
# Out:
# 38004

# %%
r4["Surgeriesamount"].sum()
# Out:
# 942326216

# %% [markdown]
# # total no of surgeries in rangareedy

# %%
rsurgeries=r1["SurgeriesCount"].sum()+r2["SurgeriesCount"].sum()+r3["SurgeriesCount"].sum()+r4["SurgeriesCount"].sum()
rsurgeries
# Out:
# 135551

# %% [markdown]
# # total amount spent

# %%
ramount=r1["Surgeriesamount"].sum()+r2["Surgeriesamount"].sum()+r3["Surgeriesamount"].sum()+r4["Surgeriesamount"].sum()
ramount
# Out:
# 3460056126

# %%
ni=df1[df1["District"]=="Nizamabad"]
ni.head()
# Out:
#     Financial Year   District Constituency  Preauth Initiated Count  \
# 510      2012-2013  Nizamabad        Armur                        2
# 511      2013-2014  Nizamabad        Armur                       50
# 512      2014-2015  Nizamabad        Armur                     1607
# 513      2015-2016  Nizamabad        Armur                     1727
# 514      2016-2017  Nizamabad        Armur                     1724
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 510                    540000                       2
# 511                   1793877                      50
# 512                  43386842                    1502
# 513                  48015903                    1625
# 514                  44692403                    1633
#
#      Preauth Approved Amount  SurgeriesCount  Surgeriesamount
# 510                   540000               2           540000
# 511                  1786514              49          1741514
# ...

# %%
I1=ni[ni["Financial Year"]=="2014-2015"]
I1
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 512      2014-2015  Nizamabad              Armur                     1607
# 517      2014-2015  Nizamabad           Balkonda                     1694
# 523      2014-2015  Nizamabad           Banswada                     1658
# 528      2014-2015  Nizamabad             Bodhan                     1741
# 535      2014-2015  Nizamabad        Jukkal (SC)                     1096
# 540      2014-2015  Nizamabad          Kamareddy                     1740
# 548      2014-2015  Nizamabad  Nizamabad (Rural)                     4388
# 555      2014-2015  Nizamabad         Yellareddy                     1573
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 512                  43386842                    1502
# 517                  45432100                    1594
# 523                  41946873                    1553
# 528                  48097976                    1617
# ...

# %%
I1["SurgeriesCount"].sum()
# Out:
# 14474

# %%
I1["Surgeriesamount"].sum()
# Out:
# 373107196

# %%
I2=ni[ni["Financial Year"]=="2015-2016"]
I2
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 513      2015-2016  Nizamabad              Armur                     1727
# 518      2015-2016  Nizamabad           Balkonda                     1682
# 524      2015-2016  Nizamabad           Banswada                     1756
# 529      2015-2016  Nizamabad             Bodhan                     1902
# 536      2015-2016  Nizamabad        Jukkal (SC)                     1274
# 541      2015-2016  Nizamabad          Kamareddy                     2053
# 549      2015-2016  Nizamabad  Nizamabad (Rural)                     4893
# 556      2015-2016  Nizamabad         Yellareddy                     1879
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 513                  48015903                    1625
# 518                  46344411                    1587
# 524                  44097249                    1671
# 529                  54550373                    1784
# ...

# %%
I2["SurgeriesCount"].sum()
# Out:
# 16245

# %%
I2["Surgeriesamount"].sum()
# Out:
# 422500697

# %%
I3=ni[ni["Financial Year"]=="2016-2017"]
I3
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 514      2016-2017  Nizamabad              Armur                     1724
# 519      2016-2017  Nizamabad           Balkonda                     1722
# 525      2016-2017  Nizamabad           Banswada                     1828
# 530      2016-2017  Nizamabad             Bodhan                     2079
# 537      2016-2017  Nizamabad        Jukkal (SC)                     1452
# 542      2016-2017  Nizamabad          Kamareddy                     2362
# 550      2016-2017  Nizamabad  Nizamabad (Rural)                     5109
# 557      2016-2017  Nizamabad         Yellareddy                     2078
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 514                  44692403                    1633
# 519                  42164161                    1641
# 525                  47466780                    1735
# 530                  55858742                    1949
# ...

# %%
I3["SurgeriesCount"].sum()
# Out:
# 17353

# %%
I3["Surgeriesamount"].sum()
# Out:
# 441164561

# %%
I4=ni[ni["Financial Year"]=="2017-2018"]
I4
# Out:
#     Financial Year   District       Constituency  Preauth Initiated Count  \
# 515      2017-2018  Nizamabad              Armur                     1912
# 520      2017-2018  Nizamabad           Balkonda                     2030
# 526      2017-2018  Nizamabad           Banswada                     2372
# 531      2017-2018  Nizamabad             Bodhan                     2279
# 538      2017-2018  Nizamabad        Jukkal (SC)                     1828
# 543      2017-2018  Nizamabad          Kamareddy                     2803
# 551      2017-2018  Nizamabad  Nizamabad (Rural)                     5961
# 558      2017-2018  Nizamabad         Yellareddy                     2530
#
#      Preauth Initiated Amount  Preauth Approved Count  \
# 515                  49578053                    1814
# 520                  57675827                    1936
# 526                  58634959                    2243
# 531                  62015168                    2164
# ...

# %%
I4["SurgeriesCount"].sum()
# Out:
# 20559

# %%
I4["Surgeriesamount"].sum()
# Out:
# 514365978

# %% [markdown]
# # total no of surgeries in nizambad

# %%
nisur=I1["SurgeriesCount"].sum()+I2["SurgeriesCount"].sum()+I3["SurgeriesCount"].sum()+I4["SurgeriesCount"].sum()
nisur
# Out:
# 68631

# %% [markdown]
# # total amount  spent  in nizambad

# %%
totalni=I1["Surgeriesamount"].sum()+I2["Surgeriesamount"].sum()+I3["Surgeriesamount"].sum()+I4["Surgeriesamount"].sum()
totalni
# Out:
# 1751138432
